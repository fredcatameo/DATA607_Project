# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/silver_20250322_Airline_Reviews_LostLuggageLabel.csv")
print(len(df))
df.head()
# Out:
# 24354
#    RowId   Airline Name  Overall_Rating  \
# 0      0    AB Aviation             9.0
# 1      1    AB Aviation             1.0
# 2      2    AB Aviation             1.0
# 3      3  Adria Airways             1.0
# 4      4  Adria Airways             1.0
#
#                             Review_Title Review Date  Verified  \
# 0                "pretty decent airline"  2019-11-11      True
# 1                   "Not a good airline"  2019-06-25      True
# 2         "flight was fortunately short"  2019-06-25      True
# 3    "I will never fly again with Adria"  2019-09-28     False
# 4  "it ruined our last days of holidays"  2019-09-24      True
#
#                                               Review  \
# 0    Moroni to Moheli. Turned out to be a pretty ...
# 1   Moroni to Anjouan. It is a very small airline...
# 2    Anjouan to Dzaoudzi. A very small airline an...
# 3    Please do a favor yourself and do not fly wi...
# 4   Do not book a flight with this airline! My fr...
#
#                                 Top Review Image Url       Aircraft  \
# 0  https://www.airlinequality.com/wp-content/uplo...            NaN
# 1                                                NaN           E120
# 2                                                NaN  Embraer E120
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   Type Of Traveller  ... Wifi & Connectivity Value For Money Recommended  \
# 0      Solo Leisure  ...                 NaN             3.0         yes
# 1      Solo Leisure  ...                 NaN             2.0          no
# 2      Solo Leisure  ...                 NaN             2.0          no
# 3      Solo Leisure  ...                 NaN             1.0          no
# 4    Couple Leisure  ...                 1.0             1.0          no
#
#                                                   Id  sentiment_label  \
# 0  d5735d894b4092e822168ba53a488a01fea59947c7b592...         positive
# 1  7966382a7e6a7378845e6e7606deb05c3cd22ed48eb139...         negative
# 2  b7272f236f9dd03ff3ddc7890a8c56ef10e4b453f87626...          neutral
# 3  2a1ca52e66cecb27b117aaa639137b03a903771bdc3581...         negative
# 4  0919fc2c8d770679071d9c4626486d411c386f1dcbcf1f...         negative
#
#    sentiment_scores                        review_gte_small_embeddings  \
# 0          0.918486  [-0.028402144089341164, 0.018615126609802246, ...
# 1          0.569240  [0.0009799960535019636, -0.024586396291851997,...
# 2          0.542810  [-0.03285892307758331, 0.0034137454349547625, ...
# 3          0.903330  [0.0019294274970889091, -0.012049898505210876,...
# 4          0.902472  [0.005685204640030861, -0.03634139522910118, 0...
#
#    lost_luggage_cosim  lost_luggage_kndist  is_lost_luggage_flag
# 0            0.809639             0.617027                 False
# 1            0.806561             0.621994                 False
# 2            0.815163             0.608008                 False
# 3            0.848293             0.550831                  True
# 4            0.811869             0.613402                 False
#
# [5 rows x 28 columns]

# %%
df['Review Date'] = pd.to_datetime(df['Review Date'], format="mixed")
print(len(df))
df.head()
# Out:
# 24354
#    RowId   Airline Name  Overall_Rating  \
# 0      0    AB Aviation             9.0
# 1      1    AB Aviation             1.0
# 2      2    AB Aviation             1.0
# 3      3  Adria Airways             1.0
# 4      4  Adria Airways             1.0
#
#                             Review_Title Review Date  Verified  \
# 0                "pretty decent airline"  2019-11-11      True
# 1                   "Not a good airline"  2019-06-25      True
# 2         "flight was fortunately short"  2019-06-25      True
# 3    "I will never fly again with Adria"  2019-09-28     False
# 4  "it ruined our last days of holidays"  2019-09-24      True
#
#                                               Review  \
# 0    Moroni to Moheli. Turned out to be a pretty ...
# 1   Moroni to Anjouan. It is a very small airline...
# 2    Anjouan to Dzaoudzi. A very small airline an...
# 3    Please do a favor yourself and do not fly wi...
# 4   Do not book a flight with this airline! My fr...
#
#                                 Top Review Image Url       Aircraft  \
# 0  https://www.airlinequality.com/wp-content/uplo...            NaN
# 1                                                NaN           E120
# 2                                                NaN  Embraer E120
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   Type Of Traveller  ... Wifi & Connectivity Value For Money Recommended  \
# 0      Solo Leisure  ...                 NaN             3.0         yes
# 1      Solo Leisure  ...                 NaN             2.0          no
# 2      Solo Leisure  ...                 NaN             2.0          no
# 3      Solo Leisure  ...                 NaN             1.0          no
# 4    Couple Leisure  ...                 1.0             1.0          no
#
#                                                   Id  sentiment_label  \
# 0  d5735d894b4092e822168ba53a488a01fea59947c7b592...         positive
# 1  7966382a7e6a7378845e6e7606deb05c3cd22ed48eb139...         negative
# 2  b7272f236f9dd03ff3ddc7890a8c56ef10e4b453f87626...          neutral
# 3  2a1ca52e66cecb27b117aaa639137b03a903771bdc3581...         negative
# 4  0919fc2c8d770679071d9c4626486d411c386f1dcbcf1f...         negative
#
#    sentiment_scores                        review_gte_small_embeddings  \
# 0          0.918486  [-0.028402144089341164, 0.018615126609802246, ...
# 1          0.569240  [0.0009799960535019636, -0.024586396291851997,...
# 2          0.542810  [-0.03285892307758331, 0.0034137454349547625, ...
# 3          0.903330  [0.0019294274970889091, -0.012049898505210876,...
# 4          0.902472  [0.005685204640030861, -0.03634139522910118, 0...
#
#    lost_luggage_cosim  lost_luggage_kndist  is_lost_luggage_flag
# 0            0.809639             0.617027                 False
# 1            0.806561             0.621994                 False
# 2            0.815163             0.608008                 False
# 3            0.848293             0.550831                  True
# 4            0.811869             0.613402                 False
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Correct Overall_Rating 10 bug

# %%
df_20250324 = pd.read_csv("../data/bronze_20250324_Airline_Reviews_withImageUrls.csv")
print(len(df_20250324))
df_20250324.head()
# Out:
# 24354
#    Unnamed: 0   Airline Name Overall_Rating  \
# 0           0    AB Aviation              9
# 1           1    AB Aviation              1
# 2           2    AB Aviation              1
# 3           3  Adria Airways              1
# 4           4  Adria Airways              1
#
#                             Review_Title          Review Date  Verified  \
# 0                "pretty decent airline"   11th November 2019      True
# 1                   "Not a good airline"       25th June 2019      True
# 2         "flight was fortunately short"       25th June 2019      True
# 3    "I will never fly again with Adria"  28th September 2019     False
# 4  "it ruined our last days of holidays"  24th September 2019      True
#
#                                               Review  \
# 0    Moroni to Moheli. Turned out to be a pretty ...
# 1   Moroni to Anjouan. It is a very small airline...
# 2    Anjouan to Dzaoudzi. A very small airline an...
# 3    Please do a favor yourself and do not fly wi...
# 4   Do not book a flight with this airline! My fr...
#
#                                 Top Review Image Url       Aircraft  \
# 0  https://www.airlinequality.com/wp-content/uplo...            NaN
# 1                                                NaN           E120
# 2                                                NaN  Embraer E120
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   Type Of Traveller  ...                             Route      Date Flown  \
# 0      Solo Leisure  ...                  Moroni to Moheli   November 2019
# 1      Solo Leisure  ...                 Moroni to Anjouan       June 2019
# 2      Solo Leisure  ...               Anjouan to Dzaoudzi       June 2019
# 3      Solo Leisure  ...             Frankfurt to Pristina  September 2019
# 4    Couple Leisure  ...  Sofia to Amsterdam via Ljubljana  September 2019
#
#   Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# 0          4.0                  5.0               4.0             4.0
# 1          2.0                  2.0               1.0             1.0
# 2          2.0                  1.0               1.0             1.0
# 3          1.0                  1.0               NaN             1.0
# 4          1.0                  1.0               1.0             1.0
#
#    Inflight Entertainment  Wifi & Connectivity  Value For Money  Recommended
# 0                     NaN                  NaN              3.0          yes
# 1                     NaN                  NaN              2.0           no
# 2                     NaN                  NaN              2.0           no
# 3                     NaN                  NaN              1.0           no
# 4                     1.0                  1.0              1.0           no
#
# [5 rows x 21 columns]

# %%
df_20250324.rename(columns={"Unnamed: 0": "RowId"}, inplace=True)
print(len(df_20250324))
df_20250324.head()
# Out:
# 24354
#    RowId   Airline Name Overall_Rating                           Review_Title  \
# 0      0    AB Aviation              9                "pretty decent airline"
# 1      1    AB Aviation              1                   "Not a good airline"
# 2      2    AB Aviation              1         "flight was fortunately short"
# 3      3  Adria Airways              1    "I will never fly again with Adria"
# 4      4  Adria Airways              1  "it ruined our last days of holidays"
#
#            Review Date  Verified  \
# 0   11th November 2019      True
# 1       25th June 2019      True
# 2       25th June 2019      True
# 3  28th September 2019     False
# 4  24th September 2019      True
#
#                                               Review  \
# 0    Moroni to Moheli. Turned out to be a pretty ...
# 1   Moroni to Anjouan. It is a very small airline...
# 2    Anjouan to Dzaoudzi. A very small airline an...
# 3    Please do a favor yourself and do not fly wi...
# 4   Do not book a flight with this airline! My fr...
#
#                                 Top Review Image Url       Aircraft  \
# 0  https://www.airlinequality.com/wp-content/uplo...            NaN
# 1                                                NaN           E120
# 2                                                NaN  Embraer E120
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   Type Of Traveller  ...                             Route      Date Flown  \
# 0      Solo Leisure  ...                  Moroni to Moheli   November 2019
# 1      Solo Leisure  ...                 Moroni to Anjouan       June 2019
# 2      Solo Leisure  ...               Anjouan to Dzaoudzi       June 2019
# 3      Solo Leisure  ...             Frankfurt to Pristina  September 2019
# 4    Couple Leisure  ...  Sofia to Amsterdam via Ljubljana  September 2019
#
#   Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# 0          4.0                  5.0               4.0             4.0
# 1          2.0                  2.0               1.0             1.0
# 2          2.0                  1.0               1.0             1.0
# 3          1.0                  1.0               NaN             1.0
# 4          1.0                  1.0               1.0             1.0
#
#    Inflight Entertainment  Wifi & Connectivity  Value For Money  Recommended
# 0                     NaN                  NaN              3.0          yes
# 1                     NaN                  NaN              2.0           no
# 2                     NaN                  NaN              2.0           no
# 3                     NaN                  NaN              1.0           no
# 4                     1.0                  1.0              1.0           no
#
# [5 rows x 21 columns]

# %%
df_20250324['Review Date'] = pd.to_datetime(df_20250324['Review Date'], format="mixed")
print(len(df_20250324))
df_20250324.head()
# Out:
# 24354
#    RowId   Airline Name Overall_Rating                           Review_Title  \
# 0      0    AB Aviation              9                "pretty decent airline"
# 1      1    AB Aviation              1                   "Not a good airline"
# 2      2    AB Aviation              1         "flight was fortunately short"
# 3      3  Adria Airways              1    "I will never fly again with Adria"
# 4      4  Adria Airways              1  "it ruined our last days of holidays"
#
#   Review Date  Verified                                             Review  \
# 0  2019-11-11      True    Moroni to Moheli. Turned out to be a pretty ...
# 1  2019-06-25      True   Moroni to Anjouan. It is a very small airline...
# 2  2019-06-25      True    Anjouan to Dzaoudzi. A very small airline an...
# 3  2019-09-28     False    Please do a favor yourself and do not fly wi...
# 4  2019-09-24      True   Do not book a flight with this airline! My fr...
#
#                                 Top Review Image Url       Aircraft  \
# 0  https://www.airlinequality.com/wp-content/uplo...            NaN
# 1                                                NaN           E120
# 2                                                NaN  Embraer E120
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#   Type Of Traveller  ...                             Route      Date Flown  \
# 0      Solo Leisure  ...                  Moroni to Moheli   November 2019
# 1      Solo Leisure  ...                 Moroni to Anjouan       June 2019
# 2      Solo Leisure  ...               Anjouan to Dzaoudzi       June 2019
# 3      Solo Leisure  ...             Frankfurt to Pristina  September 2019
# 4    Couple Leisure  ...  Sofia to Amsterdam via Ljubljana  September 2019
#
#   Seat Comfort  Cabin Staff Service  Food & Beverages  Ground Service  \
# 0          4.0                  5.0               4.0             4.0
# 1          2.0                  2.0               1.0             1.0
# 2          2.0                  1.0               1.0             1.0
# 3          1.0                  1.0               NaN             1.0
# 4          1.0                  1.0               1.0             1.0
#
#    Inflight Entertainment  Wifi & Connectivity  Value For Money  Recommended
# 0                     NaN                  NaN              3.0          yes
# 1                     NaN                  NaN              2.0           no
# 2                     NaN                  NaN              2.0           no
# 3                     NaN                  NaN              1.0           no
# 4                     1.0                  1.0              1.0           no
#
# [5 rows x 21 columns]

# %%
df_20250324_to_correct = df_20250324[df_20250324['Overall_Rating'] == '10']
print(len(df_20250324_to_correct))
df_20250324_to_correct.head()
# Out:
# 2471
#     RowId   Airline Name Overall_Rating                      Review_Title  \
# 15     15  Adria Airways             10     "Flight was very comfortable"
# 23     23  Adria Airways             10    "nice and comfortable flights"
# 31     31  Adria Airways             10       "Clean and fresh aircraft "
# 33     33  Adria Airways             10   "nice and professional service"
# 41     41  Adria Airways             10  "staff friendly but unobtrusive"
#
#    Review Date  Verified                                             Review  \
# 15  2018-05-04      True    Frankfurt to Ljubljana. Flight was very comf...
# 23  2016-11-10     False    Two very short flights with Adria Airways fr...
# 31  2016-07-29     False    Tallinn to Stockholm with Adria Airways. Cle...
# 33  2016-07-11     False    Two short flights with Adria Airways (Ljublj...
# 41  2015-09-02     False  Excellent flights both ways with Adria Airways...
#
#    Top Review Image Url      Aircraft Type Of Traveller  ...  \
# 15                  NaN           NaN          Business  ...
# 23                  NaN        CRJ900          Business  ...
# 31                  NaN  Canadair 700      Solo Leisure  ...
# 33                  NaN        CRJ900      Solo Leisure  ...
# 41                  NaN          A319    Family Leisure  ...
#
#                       Route    Date Flown Seat Comfort  Cabin Staff Service  \
# 15   Frankfurt to Ljubljana    April 2018          5.0                  5.0
# 23               LJU to VIE  October 2016          5.0                  5.0
# 31               TLL to ARN     July 2016          5.0                  5.0
# 33               LJU to ZRH     July 2016          5.0                  5.0
# 41  Manchester to Ljubljana   August 2015          5.0                  5.0
#
#     Food & Beverages  Ground Service  Inflight Entertainment  \
# 15               5.0             5.0                     NaN
# 23               NaN             5.0                     NaN
# 31               5.0             5.0                     NaN
# 33               NaN             5.0                     NaN
# 41               NaN             5.0                     NaN
#
#     Wifi & Connectivity  Value For Money  Recommended
# 15                  NaN              5.0          yes
# 23                  NaN              4.0          yes
# 31                  NaN              5.0          yes
# 33                  NaN              5.0          yes
# 41                  NaN              4.0          yes
#
# [5 rows x 21 columns]

# %%
right_columns_needed = ['RowId','Airline Name','Review_Title','Review Date','Overall_Rating']

df_merged= pd.merge(df, df_20250324_to_correct[right_columns_needed], on=['Airline Name','Review_Title','Review Date'], \
                    how='left', suffixes=('', '_right'))

print(len(df_merged))
df_merged[['RowId','Airline Name','Review_Title','Review Date','Overall_Rating','Overall_Rating_right','RowId_right']].head()
# Out:
# 24374
#    RowId   Airline Name                           Review_Title Review Date  \
# 0      0    AB Aviation                "pretty decent airline"  2019-11-11
# 1      1    AB Aviation                   "Not a good airline"  2019-06-25
# 2      2    AB Aviation         "flight was fortunately short"  2019-06-25
# 3      3  Adria Airways    "I will never fly again with Adria"  2019-09-28
# 4      4  Adria Airways  "it ruined our last days of holidays"  2019-09-24
#
#    Overall_Rating Overall_Rating_right  RowId_right
# 0             9.0                  NaN          NaN
# 1             1.0                  NaN          NaN
# 2             1.0                  NaN          NaN
# 3             1.0                  NaN          NaN
# 4             1.0                  NaN          NaN

# %%
df_merged.drop(columns=['RowId_right'], inplace=True)

#df_merged.rename(columns={"Overall_Rating_right": "Overall_Rating"}, inplace=True)
df_merged['Overall_Rating'] = np.where(df_merged['Overall_Rating_right'].isna(), df_merged['Overall_Rating'], df_merged['Overall_Rating_right'])

df_merged.drop(columns=['Overall_Rating_right'], inplace=True)

df_corrected_overallrating10 = df_merged

print(len(df_corrected_overallrating10))
df_corrected_overallrating10[['RowId','Airline Name','Review_Title','Review Date','Overall_Rating']].head()
# Out:
# 24374
#    RowId   Airline Name                           Review_Title Review Date  \
# 0      0    AB Aviation                "pretty decent airline"  2019-11-11
# 1      1    AB Aviation                   "Not a good airline"  2019-06-25
# 2      2    AB Aviation         "flight was fortunately short"  2019-06-25
# 3      3  Adria Airways    "I will never fly again with Adria"  2019-09-28
# 4      4  Adria Airways  "it ruined our last days of holidays"  2019-09-24
#
#   Overall_Rating
# 0            9.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0

# %% [markdown]
# #### Check corrected

# %%
df_corrected_overallrating10[df_corrected_overallrating10['Overall_Rating'] == '10']

print(len(df_corrected_overallrating10[df_corrected_overallrating10['Overall_Rating'] == '10']))
df_corrected_overallrating10[df_corrected_overallrating10['Overall_Rating'] == '10'].head()
# Out:
# 2530
#     RowId   Airline Name Overall_Rating                      Review_Title  \
# 15     15  Adria Airways             10     "Flight was very comfortable"
# 23     23  Adria Airways             10    "nice and comfortable flights"
# 31     31  Adria Airways             10       "Clean and fresh aircraft "
# 33     33  Adria Airways             10   "nice and professional service"
# 41     41  Adria Airways             10  "staff friendly but unobtrusive"
#
#    Review Date  Verified                                             Review  \
# 15  2018-05-04      True    Frankfurt to Ljubljana. Flight was very comf...
# 23  2016-11-10     False    Two very short flights with Adria Airways fr...
# 31  2016-07-29     False    Tallinn to Stockholm with Adria Airways. Cle...
# 33  2016-07-11     False    Two short flights with Adria Airways (Ljublj...
# 41  2015-09-02     False  Excellent flights both ways with Adria Airways...
#
#    Top Review Image Url      Aircraft Type Of Traveller  ...  \
# 15                  NaN           NaN          Business  ...
# 23                  NaN        CRJ900          Business  ...
# 31                  NaN  Canadair 700      Solo Leisure  ...
# 33                  NaN        CRJ900      Solo Leisure  ...
# 41                  NaN          A319    Family Leisure  ...
#
#    Wifi & Connectivity Value For Money Recommended  \
# 15                 NaN             5.0         yes
# 23                 NaN             4.0         yes
# 31                 NaN             5.0         yes
# 33                 NaN             5.0         yes
# 41                 NaN             4.0         yes
#
#                                                    Id  sentiment_label  \
# 15  b699dd2190da59dd645675255903bb1e4a7a3f36f35fb9...         positive
# 23  587cffef6f68bed92ce8f89d7bc080194728db889287ce...         positive
# 31  0083216ab1d562c61d0cffe588a6ec720e71dbb8cc83ac...         positive
# 33  9a3abcbd6c1bdcaf98d573e84e1ea501892773da03c2cb...         positive
# 41  8fdef15a566a4a88f5576fb91bb54503d621180af56a73...         positive
#
#     sentiment_scores                        review_gte_small_embeddings  \
# 15          0.873290  [0.019111955538392067, 0.034589145332574844, 0...
# 23          0.931223  [-0.004835888277739286, -0.012767900712788105,...
# 31          0.908528  [0.00028129376005381346, -0.034618716686964035...
# 33          0.924249  [-0.01605038158595562, 0.01549801416695118, 0....
# 41          0.960242  [0.011958998627960682, -0.024617895483970642, ...
#
#     lost_luggage_cosim  lost_luggage_kndist  is_lost_luggage_flag
# 15            0.779751             0.663700                 False
# 23            0.783593             0.657885                 False
# 31            0.759344             0.693767                 False
# 33            0.784087             0.657134                 False
# 41            0.763106             0.688323                 False
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Persist to CSV file

# %%
df_corrected_overallrating10.to_csv("../data/silver_20250322_Airline_Reviews_LostLuggageLabel", index=False, date_format='%Y-%m-%d')
